# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
data=pd.read_csv('sell.csv')
data
# Out:
#      account number                           name       sku category  \
# 0            296809                    Carroll PLC  QN-82852     Belt
# 1             98022              Heidenreich-Bosco  MJ-21460    Shoes
# 2            563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt
# 3             93356                  Waters-Walker  AS-93055    Shirt
# 4            659366                  Waelchi-Fahey  AS-93055    Shirt
# ..              ...                            ...       ...      ...
# 995          758133      Kihn, McClure and Denesik  WJ-02096     Belt
# 996          850140                      Kunze Inc  GS-86623    Shoes
# 997           93356                  Waters-Walker  GS-86623    Shoes
# 998          304860                      Huel-Haag  LL-46261    Shoes
# 999           98022              Heidenreich-Bosco  LW-86841    Shoes
#
#      quantity  unit price  ext price                 date
# 0          13       44.48     578.24  2014-09-27 07:13:03
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
data.columns
# Out:
# Index(['account number', 'name', 'sku', 'category', 'quantity', 'unit price',
#        'ext price', 'date'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    account number                           name       sku category  quantity  \
# 0          296809                    Carroll PLC  QN-82852     Belt        13
# 1           98022              Heidenreich-Bosco  MJ-21460    Shoes        19
# 2          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12
# 3           93356                  Waters-Walker  AS-93055    Shirt         5
# 4          659366                  Waelchi-Fahey  AS-93055    Shirt        18
# 5          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        17
# 6          995267                  Cole-Eichmann  GS-86623    Shoes        18
# 7          524021               Hegmann and Sons  LL-46261    Shoes         7
# 8          929400  Senger, Upton and Breitenberg  LW-86841    Shoes        17
# 9          563905  Kerluke, Reilly and Bechtelar  KV-99194    Shirt        12
#
#    unit price  ext price                 date
# 0       44.48     578.24  2014-09-27 07:13:03
# ...

# %%
#on the basis of 'unit price' provide the mean of that 'unit price'.
pivot1=pd.pivot_table(data,index=['account number','name','category'],values=['quantity'])
#pivot1=pd.pivot_table(data,index=['account number','name','category'])
pivot1.head(15)
# Out:
#                                             quantity
# account number name              category
# 93356          Waters-Walker     Belt      13.833333
#                                  Shirt     12.000000
#                                  Shoes     10.350000
# 98022          Heidenreich-Bosco Belt      10.600000
#                                  Shirt      9.200000
#                                  Shoes     11.650000
# 115138         Gorczany-Hahn     Belt       8.583333
#                                  Shirt     11.285714
#                                  Shoes     11.111111
# 201259         Koelpin PLC       Belt       9.500000
#                                  Shirt      8.800000
#                                  Shoes      9.666667
# 296809         Carroll PLC       Belt      13.142857
#                                  Shirt     11.681818
#                                  Shoes     11.238095

# %%
#we can give multiple value as well.
pivot1=pd.pivot_table(data,index=['name','category'],values=['quantity','unit price'])
pivot1.head(15)
# Out:
#                                         quantity  unit price
# name                         category
# Berge LLC                    Belt      13.333333   50.106667
#                              Shirt      8.300000   61.327000
#                              Shoes     10.260870   60.844348
# Carroll PLC                  Belt      13.142857   52.359286
#                              Shirt     11.681818   49.951364
#                              Shoes     11.238095   53.109048
# Cole-Eichmann                Belt      11.307692   49.282308
#                              Shirt     11.238095   58.416667
#                              Shoes      9.117647   56.798824
# Davis, Kshlerin and Reilly   Belt       5.500000   51.561667
#                              Shirt     10.062500   51.781875
#                              Shoes      9.736842   52.646316
# Ernser, Cruickshank and Lind Belt      10.777778   62.755556
#                              Shirt     10.916667   62.510417
# ...

# %%
#checking a mean of carroll plc
data[data['name'].str.contains('Carroll') & (data['category']=='Belt')]['quantity'].mean()
# Out:
# 13.142857142857142

# %%
pivot1.loc[['Koelpin PLC','category']]
# Out:
#                       quantity  unit price
# name        category
# Koelpin PLC Belt      9.500000   39.416429
#             Shirt     8.800000   52.404667
#             Shoes     9.666667   56.240000

# %%
pd.pivot_table(data,index=['name','category'],values=['quantity'],aggfunc=[np.mean,len]).head(15)
#len is used for calculate the total quantity of something by that people.
# Out:
#                                             mean      len
#                                         quantity quantity
# name                         category
# Berge LLC                    Belt      13.333333        9
#                              Shirt      8.300000       20
#                              Shoes     10.260870       23
# Carroll PLC                  Belt      13.142857       14
#                              Shirt     11.681818       22
#                              Shoes     11.238095       21
# Cole-Eichmann                Belt      11.307692       13
#                              Shirt     11.238095       21
#                              Shoes      9.117647       17
# Davis, Kshlerin and Reilly   Belt       5.500000        6
#                              Shirt     10.062500       16
#                              Shoes      9.736842       19
# Ernser, Cruickshank and Lind Belt      10.777778        9
#                              Shirt     10.916667       24
# ...

# %%
#lets verify that data.
data[data['name'].str.contains(r'Berge')]['category'].value_counts()
# Out:
# Shoes    23
# Shirt    20
# Belt      9
# Name: category, dtype: int64

# %%
pd.pivot_table(data,index=['name',],columns=['category'],values=['ext price'],aggfunc=[np.mean,np.sum,len])
# Out:
#                                      mean                               sum  \
#                                 ext price                         ext price
# category                             Belt       Shirt       Shoes      Belt
# name
# Berge LLC                      670.392222  483.512000  624.395652   6033.53
# Carroll PLC                    668.518571  623.527727  612.259048   9359.26
# Cole-Eichmann                  624.053846  691.810000  458.512353   8112.70
# Davis, Kshlerin and Reilly     267.355000  470.814375  521.978947   1604.13
# Ernser, Cruickshank and Lind   654.931111  706.007917  375.032143   5894.38
# Gorczany-Hahn                  303.540000  598.896667  665.398889   3642.48
# Hamill-Hackett                 402.435000  522.355294  562.782609   1609.74
# Hegmann and Sons               490.938000  645.171923  614.994091   4909.38
# Heidenreich-Bosco              626.294000  596.525000  660.005000   6262.94
# ...

# %%
pd.pivot_table(data,index=['name'],values=['ext price'],aggfunc=[np.mean,np.sum,len]).max()
# Out:
# mean  ext price      735.5792
# sum   ext price    38935.2900
# len   ext price       59.0000
# dtype: float64

# %%
pd.pivot_table(data,index=['name'],values=['ext price'],columns=['category'],aggfunc=[np.mean,np.sum,len])
# Out:
#                                      mean                               sum  \
#                                 ext price                         ext price
# category                             Belt       Shirt       Shoes      Belt
# name
# Berge LLC                      670.392222  483.512000  624.395652   6033.53
# Carroll PLC                    668.518571  623.527727  612.259048   9359.26
# Cole-Eichmann                  624.053846  691.810000  458.512353   8112.70
# Davis, Kshlerin and Reilly     267.355000  470.814375  521.978947   1604.13
# Ernser, Cruickshank and Lind   654.931111  706.007917  375.032143   5894.38
# Gorczany-Hahn                  303.540000  598.896667  665.398889   3642.48
# Hamill-Hackett                 402.435000  522.355294  562.782609   1609.74
# Hegmann and Sons               490.938000  645.171923  614.994091   4909.38
# Heidenreich-Bosco              626.294000  596.525000  660.005000   6262.94
# ...

# %%
pd.pivot_table(data,index=['name'],values=['ext price'],columns=['category'],
            aggfunc=[np.mean,np.sum,len],fill_value=0,margins=True,margins_name='Total')
#total= sum of all the mean values.
# Out:
#                                      mean                                      \
#                                 ext price
# category                             Belt       Shirt       Shoes       Total
# name
# Berge LLC                      670.392222  483.512000  624.395652  578.170577
# Carroll PLC                    668.518571  623.527727  612.259048  630.426491
# Cole-Eichmann                  624.053846  691.810000  458.512353  596.772941
# Davis, Kshlerin and Reilly     267.355000  470.814375  521.978947  464.750244
# Ernser, Cruickshank and Lind   654.931111  706.007917  375.032143  597.638723
# Gorczany-Hahn                  303.540000  598.896667  665.398889  528.759524
# Hamill-Hackett                 402.435000  522.355294  562.782609  532.585909
# Hegmann and Sons               490.938000  645.171923  614.994091  607.133103
# Heidenreich-Bosco              626.294000  596.525000  660.005000  635.707250
# ...

# %%
pd.pivot_table(data,index=['name'],columns=['category'],values=['ext price','quantity'],
               aggfunc={"quentity":len,"ext price":np.sum},margins=True)
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-59-ae2633d8def1> in <module>
# ----> 1 pd.pivot_table(data,index=['name'],columns=['category'],values=['ext price','quantity'],
#       2                aggfunc={"quentity":len,"ext price":np.sum},margins=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      99
#     100     grouped = data.groupby(keys, observed=observed)
# --> 101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     103         agged = agged.dropna(how="all")
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     926         func = _maybe_mangle_lambdas(func)
#     927
# ...
