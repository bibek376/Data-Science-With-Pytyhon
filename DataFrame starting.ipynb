# %%
import numpy as np
import pandas as pd
import webbrowser
web='https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'
webbrowser.open(web)
# Out:
# True

# %%
data=pd.read_clipboard()

# %%
data
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers   1368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears   1402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers   1034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,203  630   552    21  0.532
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %%
data.head()
# Out:
#    Rank                  Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys   914  520   388     6  0.572              1960
# 1     2     Green Bay Packers  1368  756   574    38  0.567              1921
# 2     3  New England Patriots   916  512   395     9  0.564              1960
# 3     4         Chicago Bears  1402  769   591    42  0.563              1920
# 4     5      Baltimore Ravens   384  214   169     1  0.559              1996
#
#     Division
# 0   NFC East
# 1  NFC North
# 2   AFC East
# 3  NFC North
# 4  AFC North

# %%
data.tail()
# Out:
#     Rank                 Team     GP  Won  Lost  Tied   Pct.  \
# 11    12  Pittsburgh Steelers  1,203  630   552    21  0.532
# 12    13   Indianapolis Colts    998  523   468     7  0.528
# 13    14    Las Vegas Raiders    916  473   432    11  0.522
# 14    15     Seattle Seahawks    692  355   336     1  0.514
# 15    16     Los Angeles Rams  1,167  577   569    21  0.503
#
#     First NFL Season   Division
# 11              1933  AFC North
# 12              1953  AFC South
# 13              1960   AFC West
# 14              1976   NFC West
# 15              1937   NFC West

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16, step=1)

# %%
pd.DataFrame(data,columns=['Rank','Team','GP']).head()
# Out:
#    Rank                  Team    GP
# 0     1        Dallas Cowboys   914
# 1     2     Green Bay Packers  1368
# 2     3  New England Patriots   916
# 3     4         Chicago Bears  1402
# 4     5      Baltimore Ravens   384

# %%
data.Team.head()
# Out:
# 0          Dallas Cowboys
# 1       Green Bay Packers
# 2    New England Patriots
# 3           Chicago Bears
# 4        Baltimore Ravens
# Name: Team, dtype: object

# %%
data['Lost'].tail()
# Out:
# 11    552
# 12    468
# 13    432
# 14    336
# 15    569
# Name: Lost, dtype: int64

# %%
data.iloc[1]
# Out:
# Rank                                2
# Team                Green Bay Packers
# GP                               1368
# Won                               756
# Lost                              574
# Tied                               38
# Pct.                            0.567
# First NFL Season                 1921
# Division                    NFC North
# Name: 1, dtype: object

# %%
data
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers   1368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears   1402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers   1034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,203  630   552    21  0.532
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %%
data['stedium']=np.nan

# %%
data
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers   1368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears   1402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers   1034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,203  630   552    21  0.532
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %%
stm=pd.Series(['AT','Bs'],index=[0,4])
data['stedium']=stm
data
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers   1368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears   1402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers   1034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,203  630   552    21  0.532
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %%
#deleting a stedium column
del data['stedium']

# %%
data
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers   1368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears   1402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers   1034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,203  630   552    21  0.532
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %%
df={'name':['bibek','carlos','binaya','bikash'],'country':['germany','usa','aus','nepal']}
df1=pd.DataFrame(df)
df1
# Out:
#      name  country
# 0   bibek  germany
# 1  carlos      usa
# 2  binaya      aus
# 3  bikash    nepal

# %%
#reindex
import numpy as np
ser1=pd.Series([1,2,3],index=['a','b','c'])
ser1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser2=ser1.reindex(['a','bbb','c','d'])
ser2
# Out:
# a      1.0
# bbb    NaN
# c      3.0
# d      NaN
# dtype: float64

# %%
ser2.reindex(['a','bbb','c','d'],f)
